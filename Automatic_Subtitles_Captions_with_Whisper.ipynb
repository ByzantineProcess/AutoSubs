# %% [markdown]
# # Automatic Subtitles/Captions for Creators
#
# This is a tool that leverages OpenAI's Whisper ML model in order to generate subtitles for online media.
#
# Before we start, go to 'Edit', and click 'Notebook Settings'.
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Then set 'Hardware Accelerator' to 'GPU'.
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
# To start, press 'Connect'.
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Upload your final video/audio
#
# Open the File pane, then upload either your final video or audio with the filename `main` (doesn't matter what extension it is, we'll figure it out)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Final Steps
#
# From here on out, we have it covered.
#
# Now just press `Ctrl+F9` or head to `Runtime -> Run all` and we take care of the rest.
#
# Once it has finished, you will see a .SRT file in the Files pane. Just download it, and disconnect from the Colab runtime (or just close the tab). All files in a Colab instance are deleted after disconnecting.

# %%
# !pip install openai-whisper -U
# !apt install ffmpeg

# Convert any file provided into main.mp3
# !ffmpeg -i ./main.* ./main.mp3

# !whisper ./main.mp3 --model large
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
print("I'm active!")
# Out:
# I'm active!
